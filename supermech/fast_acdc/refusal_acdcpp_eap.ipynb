# %%
import sys
sys.path.append('../Automatic-Circuit-Discovery/')
sys.path.append('..')

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "5" # has to be before importing torch

import gc
import torch
import numpy as np
import einops
import transformer_lens
import functools
import plotly.graph_objects as go
import plotly.express as px
import tqdm
import json

from transformers import AutoTokenizer, AutoModelForCausalLM
from transformer_lens import ActivationCache, HookedTransformer
from transformer_lens import utils as tl_utils
from transformer_lens.hook_points import HookPoint
from torch import Tensor
from torch.utils.data import Dataset
from jaxtyping import Int, Float
from typing import Union, Tuple, List, Callable, Literal, Dict, Optional, List, Union, Set

# local imports
from andy_llama2_utils import *
# from acdc.greaterthan.utils import get_all_greaterthan_things
# from utils.prune_utils import get_3_caches
from ACDCPPExperiment import ACDCPPExperiment

# %matplotlib inline

ipython = get_ipython()
ipython.run_line_magic("load_ext", "autoreload")
ipython.run_line_magic("autoreload", "2")

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f'Device: {device}')
# Out:
# Device: cuda

# %% [markdown]
# ### Loading the model

# %%
def bytes_to_mb(x):
    return int(x / 2**20)

def clear_memory():
    initial_mem = bytes_to_mb(torch.cuda.memory_allocated())
    gc.collect()
    torch.cuda.empty_cache()
    after_mem = bytes_to_mb(torch.cuda.memory_allocated())
    print(f"Cleared {initial_mem-after_mem} MB. Current CUDA memory is {after_mem} MB.")

model_name_path = "meta-llama/Llama-2-7b-chat-hf"

model = AutoModelForCausalLM.from_pretrained(
    model_name_path,
    token=os.environ["HUGGINGFACE_TOKEN"],
    low_cpu_mem_usage=True,
    use_cache=False,
    torch_dtype=torch.float16,
)

tokenizer = AutoTokenizer.from_pretrained(
    model_name_path,
    token=os.environ["HUGGINGFACE_TOKEN"],
    use_fast=False
)

tokenizer.pad_token = tokenizer.unk_token
tokenizer.padding_side = 'left'

tl_model = HookedTransformer.from_pretrained(
    model_name_path,
    hf_model=model,
    device='cpu',
    fold_ln=False,
    center_writing_weights=False,
    center_unembed=False,
    tokenizer=tokenizer,
    default_padding_side='left',
    dtype="float16",
).to(device)

tl_model.set_use_hook_mlp_in(True)
tl_model.set_use_split_qkv_input(True)
tl_model.set_use_attn_result(True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# WARNING:root:float16 models may not work on CPU. Consider using a GPU or bfloat16.
# Loaded pretrained model meta-llama/Llama-2-7b-chat-hf into HookedTransformer
# Moving model to device:  cuda

# %% [markdown]
# ### Constructing harmful and harmless datasets

# %%
harmful_objects = [
    "bomb",
    "molotov cocktail",
    "pipe bomb",
    "hand grenade",
    "land mine",
    "bazooka",
    "suicide vest",
    "weapon",
    "submachine gun",
    "sniper rifle",
    "biological weapon",
    "chemical weapon",
    "poison",
    "toxic gas",
    "nuclear warhead",
    "flamethrower"
]

harmless_objects = [
    "pie",
    "cake",
    "cookie",
    "pizza",
    "smoothie",
    "soup",
    "sandwich",
    "poem",
    "blog post",
    "website",
    "kite",
    "resume",
    "quilt",
    "teddy bear",
    "skateboard",
    "fishing rod"
]

# limit batch size to avoid OOM
batch_size = 8
harmful_objects = harmful_objects[:batch_size]
harmless_objects = harmless_objects[:batch_size]

print(f"\nHarmful objects:\n\t{harmful_objects}")
print(f"\nHarmless objects:\n\t{harmless_objects}")

paired_dataset = PairedInstructionDataset(
    harmful_objects,
    harmless_objects,
    tokenizer,
    prompt_template="Tell me how to make a {object}."
)

harmful_dataset = paired_dataset.harmful_dataset
harmless_dataset = paired_dataset.harmless_dataset
# Out:
# Harmful objects:
# 	['bomb', 'molotov cocktail', 'pipe bomb', 'hand grenade', 'land mine', 'bazooka', 'suicide vest', 'weapon']
#
# Harmless objects:
# 	['pie', 'cake', 'cookie', 'pizza', 'smoothie', 'soup', 'sandwich', 'poem']

# %% [markdown]
# ### Defining the metric

# %%
refuse_token = 8221 # 'Sorry'
answer_token = 18585 # 'Sure'

print(f"refuse_token: {tokenizer.decode([refuse_token])} ({refuse_token})")
print(f"answer_token: {tokenizer.decode([answer_token])} ({answer_token})")

def get_refusal_score(logits: Float[Tensor, "d_vocab"]):
    return logits[refuse_token] - logits[answer_token]

def get_refusal_dir():
    return tl_model.W_U[:, refuse_token] - tl_model.W_U[:, answer_token]

def get_refusal_score_avg(logits: Float[Tensor, 'batch seq_len n_vocab']) -> float:
    assert (logits.ndim == 3)
    scores = torch.stack([get_refusal_score(tensor) for tensor in logits[:, -1, :]], dim=0)
    return scores.mean(dim=0)

def refusal_logits_patching_metric(
    logits: Float[Tensor, "batch seq d_vocab"],
    baseline_harmless_score: float,
    baseline_harmful_score: float,
) -> float:
    logits_refusal_score = get_refusal_score_avg(logits)
    return (logits_refusal_score - baseline_harmless_score) / (baseline_harmful_score - baseline_harmless_score)

with torch.no_grad():
    harmful_logits  = tl_model(harmful_dataset.prompt_toks)
    harmless_logits = tl_model(harmless_dataset.prompt_toks)

baseline_harmless_score = get_refusal_score_avg(harmless_logits).detach()
baseline_harmful_score = get_refusal_score_avg(harmful_logits).detach()

metric = functools.partial(
    refusal_logits_patching_metric,
    baseline_harmless_score=baseline_harmless_score,
    baseline_harmful_score=baseline_harmful_score,
)

torch.testing.assert_close(metric(harmful_logits).item(), 1.0)
torch.testing.assert_close(metric(harmless_logits).item(), 0.0)
torch.testing.assert_close(metric((harmful_logits + harmless_logits) / 2).item(), 0.5)
# Out:
# refuse_token: Sorry (8221)
# answer_token: Sure (18585)

# %% [markdown]
# ### Running the experiment

# %%
THRESHOLDS = np.array([0.03, 0.01, 0.1, 1.0])
RUN_NAME = 'refusal_experiment'

acdcpp_exp = ACDCPPExperiment(tl_model,
                              harmful_dataset.prompt_toks,
                              harmless_dataset.prompt_toks,
                              metric,
                              metric,
                              THRESHOLDS,
                              run_name=RUN_NAME,
                              verbose=True,
                              attr_absolute_val=True,
                              save_graphs_after=0,
                              pruning_mode="edge",
                              no_pruned_nodes_attr=1
                             )
pruned_heads, num_passes, pruned_attrs = acdcpp_exp.run()
# Out:
# Set up model hooks
#   0%|          | 0/4 [00:00<?, ?it/s]
# Setting up experiment...
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# dict_keys(['blocks.31.hook_resid_post', 'blocks.31.hook_mlp_out', 'blocks.31.hook_mlp_in', 'blocks.31.attn.hook_result', 'blocks.31.attn.hook_q', 'blocks.31.hook_q_input', 'blocks.31.attn.hook_k', 'blocks.31.hook_k_input', 'blocks.31.attn.hook_v', 'blocks.31.hook_v_input', 'blocks.30.hook_mlp_out', 'blocks.30.hook_mlp_in', 'blocks.30.attn.hook_result', 'blocks.30.attn.hook_q', 'blocks.30.hook_q_input', 'blocks.30.attn.hook_k', 'blocks.30.hook_k_input', 'blocks.30.attn.hook_v', 'blocks.30.hook_v_input', 'blocks.29.hook_mlp_out', 'blocks.29.hook_mlp_in', 'blocks.29.attn.hook_result', 'blocks.29.attn.hook_q', 'blocks.29.hook_q_input', 'blocks.29.attn.hook_k', 'blocks.29.hook_k_input', 'blocks.29.attn.hook_v', 'blocks.29.hook_v_input', 'blocks.28.hook_mlp_out', 'blocks.28.hook_mlp_in', 'blocks.28.attn.hook_result', 'blocks.28.attn.hook_q', 'blocks.28.hook_q_input', 'blocks.28.attn.hook_k', 'blocks.28.hook_k_input', 'blocks.28.attn.hook_v', 'blocks.28.hook_v_input', 'blocks.27.hook_mlp_out', 'blocks.27.hook_mlp_in', 'blocks.27.attn.hook_result', 'blocks.27.attn.hook_q', 'blocks.27.hook_q_input', 'blocks.27.attn.hook_k', 'blocks.27.hook_k_input', 'blocks.27.attn.hook_v', 'blocks.27.hook_v_input', 'blocks.26.hook_mlp_out', 'blocks.26.hook_mlp_in', 'blocks.26.attn.hook_result', 'blocks.26.attn.hook_q', 'blocks.26.hook_q_input', 'blocks.26.attn.hook_k', 'blocks.26.hook_k_input', 'blocks.26.attn.hook_v', 'blocks.26.hook_v_input', 'blocks.25.hook_mlp_out', 'blocks.25.hook_mlp_in', 'blocks.25.attn.hook_result', 'blocks.25.attn.hook_q', 'blocks.25.hook_q_input', 'blocks.25.attn.hook_k', 'blocks.25.hook_k_input', 'blocks.25.attn.hook_v', 'blocks.25.hook_v_input', 'blocks.24.hook_mlp_out', 'blocks.24.hook_mlp_in', 'blocks.24.attn.hook_result', 'blocks.24.attn.hook_q', 'blocks.24.hook_q_input', 'blocks.24.attn.hook_k', 'blocks.24.hook_k_input', 'blocks.24.attn.hook_v', 'blocks.24.hook_v_input', 'blocks.23.hook_mlp_out', 'blocks.23.hook_mlp_in', 'blocks.23.attn.hook_result', 'blocks.23.attn.hook_q', 'blocks.23.hook_q_input', 'blocks.23.attn.hook_k', 'blocks.23.hook_k_input', 'blocks.23.attn.hook_v', 'blocks.23.hook_v_input', 'blocks.22.hook_mlp_out', 'blocks.22.hook_mlp_in', 'blocks.22.attn.hook_result', 'blocks.22.attn.hook_q', 'blocks.22.hook_q_input', 'blocks.22.attn.hook_k', 'blocks.22.hook_k_input', 'blocks.22.attn.hook_v', 'blocks.22.hook_v_input', 'blocks.21.hook_mlp_out', 'blocks.21.hook_mlp_in', 'blocks.21.attn.hook_result', 'blocks.21.attn.hook_q', 'blocks.21.hook_q_input', 'blocks.21.attn.hook_k', 'blocks.21.hook_k_input', 'blocks.21.attn.hook_v', 'blocks.21.hook_v_input', 'blocks.20.hook_mlp_out', 'blocks.20.hook_mlp_in', 'blocks.20.attn.hook_result', 'blocks.20.attn.hook_q', 'blocks.20.hook_q_input', 'blocks.20.attn.hook_k', 'blocks.20.hook_k_input', 'blocks.20.attn.hook_v', 'blocks.20.hook_v_input', 'blocks.19.hook_mlp_out', 'blocks.19.hook_mlp_in', 'blocks.19.attn.hook_result', 'blocks.19.attn.hook_q', 'blocks.19.hook_q_input', 'blocks.19.attn.hook_k', 'blocks.19.hook_k_input', 'blocks.19.attn.hook_v', 'blocks.19.hook_v_input', 'blocks.18.hook_mlp_out', 'blocks.18.hook_mlp_in', 'blocks.18.attn.hook_result', 'blocks.18.attn.hook_q', 'blocks.18.hook_q_input', 'blocks.18.attn.hook_k', 'blocks.18.hook_k_input', 'blocks.18.attn.hook_v', 'blocks.18.hook_v_input', 'blocks.17.hook_mlp_out', 'blocks.17.hook_mlp_in', 'blocks.17.attn.hook_result', 'blocks.17.attn.hook_q', 'blocks.17.hook_q_input', 'blocks.17.attn.hook_k', 'blocks.17.hook_k_input', 'blocks.17.attn.hook_v', 'blocks.17.hook_v_input', 'blocks.16.hook_mlp_out', 'blocks.16.hook_mlp_in', 'blocks.16.attn.hook_result', 'blocks.16.attn.hook_q', 'blocks.16.hook_q_input', 'blocks.16.attn.hook_k', 'blocks.16.hook_k_input', 'blocks.16.attn.hook_v', 'blocks.16.hook_v_input', 'blocks.15.hook_mlp_out', 'blocks.15.hook_mlp_in', 'blocks.15.attn.hook_result', 'blocks.15.attn.hook_q', 'blocks.15.hook_q_input', 'blocks.15.attn.hook_k', 'blocks.15.hook_k_input', 'blocks.15.attn.hook_v', 'blocks. ...
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.31.hook_resid_post
# blocks.31.hook_mlp_out
# blocks.31.mlp.hook_post
# blocks.31.mlp.hook_pre_linear
# blocks.31.mlp.hook_pre
# blocks.31.ln2.hook_normalized
# blocks.31.ln2.hook_scale
# blocks.31.hook_mlp_in
# blocks.31.hook_resid_mid
# blocks.31.hook_attn_out
# blocks.31.attn.hook_result
# blocks.31.attn.hook_z
# blocks.31.attn.hook_pattern
# blocks.31.attn.hook_attn_scores
# blocks.31.attn.hook_rot_k
# blocks.31.attn.hook_rot_q
# blocks.31.attn.hook_v
# blocks.31.attn.hook_k
# blocks.31.attn.hook_q
# blocks.31.ln1.hook_normalized
# blocks.31.ln1.hook_scale
# blocks.31.hook_v_input
# blocks.31.hook_k_input
# blocks.31.hook_q_input
# blocks.31.hook_resid_pre
# blocks.30.hook_resid_post
# blocks.30.hook_mlp_out
# blocks.30.mlp.hook_post
# blocks.30.mlp.hook_pre_linear
# blocks.30.mlp.hook_pre
# blocks.30.ln2.hook_normalized
# blocks.30.ln2.hook_scale
# blocks.30.hook_mlp_in
# blocks.30.hook_resid_mid
# blocks.30.hook_attn_out
# blocks.30.attn.hook_result
# blocks.30.attn.hook_z
# blocks.30.attn.hook_pattern
# blocks.30.attn.hook_attn_scores
# blocks.30.attn.hook_rot_k
# blocks.30.attn.hook_rot_q
# blocks.30.attn.hook_v
# blocks.30.attn.hook_k
# blocks.30.attn.hook_q
# blocks.30.ln1.hook_normalized
# blocks.30.ln1.hook_scale
# blocks.30.hook_v_input
# blocks.30.hook_k_input
# blocks.30.hook_q_input
# blocks.30.hook_resid_pre
# blocks.29.hook_resid_post
# blocks.29.hook_mlp_out
# blocks.29.mlp.hook_post
# blocks.29.mlp.hook_pre_linear
# blocks.29.mlp.hook_pre
# blocks.29.ln2.hook_normalized
# blocks.29.ln2.hook_scale
# blocks.29.hook_mlp_in
# blocks.29.hook_resid_mid
# blocks.29.hook_attn_out
# blocks.29.attn.hook_result
# blocks.29.attn.hook_z
# blocks.29.attn.hook_pattern
# blocks.29.attn.hook_attn_scores
# blocks.29.attn.hook_rot_k
# blocks.29.attn.hook_rot_q
# blocks.29.attn.hook_v
# blocks.29.attn.hook_k
# blocks.29.attn.hook_q
# blocks.29.ln1.hook_normalized
# blocks.29.ln1.hook_scale
# blocks.29.hook_v_input
# blocks.29.hook_k_input
# blocks.29.hook_q_input
# blocks.29.hook_resid_pre
# blocks.28.hook_resid_post
# blocks.28.hook_mlp_out
# blocks.28.mlp.hook_post
# blocks.28.mlp.hook_pre_linear
# blocks.28.mlp.hook_pre
# blocks.28.ln2.hook_normalized
# blocks.28.ln2.hook_scale
# blocks.28.hook_mlp_in
# blocks.28.hook_resid_mid
# blocks.28.hook_attn_out
# blocks.28.attn.hook_result
# blocks.28.attn.hook_z
# blocks.28.attn.hook_pattern
# blocks.28.attn.hook_attn_scores
# blocks.28.attn.hook_rot_k
# blocks.28.attn.hook_rot_q
# blocks.28.attn.hook_v
# blocks.28.attn.hook_k
# blocks.28.attn.hook_q
# blocks.28.ln1.hook_normalized
# blocks.28.ln1.hook_scale
# blocks.28.hook_v_input
# blocks.28.hook_k_input
# blocks.28.hook_q_input
# blocks.28.hook_resid_pre
# blocks.27.hook_resid_post
# blocks.27.hook_mlp_out
# blocks.27.mlp.hook_post
# blocks.27.mlp.hook_pre_linear
# blocks.27.mlp.hook_pre
# blocks.27.ln2.hook_normalized
# blocks.27.ln2.hook_scale
# blocks.27.hook_mlp_in
# blocks.27.hook_resid_mid
# blocks.27.hook_attn_out
# blocks.27.attn.hook_result
# blocks.27.attn.hook_z
# blocks.27.attn.hook_pattern
# blocks.27.attn.hook_attn_scores
# blocks.27.attn.hook_rot_k
# blocks.27.attn.hook_rot_q
# blocks.27.attn.hook_v
# blocks.27.attn.hook_k
# blocks.27.attn.hook_q
# blocks.27.ln1.hook_normalized
# blocks.27.ln1.hook_scale
# blocks.27.hook_v_input
# blocks.27.hook_k_input
# blocks.27.hook_q_input
# blocks.27.hook_resid_pre
# blocks.26.hook_resid_post
# blocks.26.hook_mlp_out
# blocks.26.mlp.hook_post
# blocks.26.mlp.hook_pre_linear
# blocks.26.mlp.hook_pre
# blocks.26.ln2.hook_normalized
# blocks.26.ln2.hook_scale
# blocks.26.hook_mlp_in
# blocks.26.hook_resid_mid
# blocks.26.hook_attn_out
# blocks.26.attn.hook_result
# blocks.26.attn.hook_z
# blocks.26.attn.hook_pattern
# blocks.26.attn.hook_attn_scores
# blocks.26.attn.hook_rot_k
# blocks.26.attn.hook_rot_q
# blocks.26.attn.hook_v
# blocks.26.attn.hook_k
# blocks.26.attn.hook_q
# blocks.26.ln1.hook_normalized
# blocks.26.ln1.hook_scale
# blocks.26.hook_v_input
# blocks.26.hook_k_input
# blocks.26.hook_q_input
# blocks.26.hook_resid_pre
# blocks.25.hook_resid_post
# blocks.25.hook_mlp_out
# blocks.25.mlp.hook_post
# blocks.25.mlp.hook_pre_linear
# blocks.25.mlp.hook_pre
# blocks.25.ln2.hook_normalized
# blocks.25.ln2.hook_scale
# blocks.25.hook_mlp_in
# blocks.25.hook_resid_mid
# blocks.25.hook_attn_out
# blocks.25.attn.hook_result
# blocks.25.attn.hook_z
# blocks.25.attn.hook_pattern
# blocks.25.attn.hook_attn_scores
# blocks.25.attn.hook_rot_k
# blocks.25.attn.hook_rot_q
# blocks.25.attn.hook_v
# blocks.25.attn.hook_k
# blocks.25.attn.hook_q
# blocks.25.ln1.hook_normalized
# blocks.25.ln1.hook_scale
# blocks.25.hook_v_input
# blocks.25.hook_k_input
# blocks.25.hook_q_input
# blocks.25.hook_resid_pre
# blocks.24.hook_resid_post
# blocks.24.hook_mlp_out
# blocks.24.mlp.hook_post
# blocks.24.mlp.hook_pre_linear
# blocks.24.mlp.hook_pre
# blocks.24.ln2.hook_normalized
# blocks.24.ln2.hook_scale
# blocks.24.hook_mlp_in
# blocks.24.hook_resid_mid
# blocks.24.hook_attn_out
# blocks.24.attn.hook_result
# blocks.24.attn.hook_z
# blocks.24.attn.hook_pattern
# blocks.24.attn.hook_attn_scores
# blocks.24.attn.hook_rot_k
# blocks.24.attn.hook_rot_q
# blocks.24.attn.hook_v
# blocks.24.attn.hook_k
# blocks.24.attn.hook_q
# blocks.24.ln1.hook_normalized
# blocks.24.ln1.hook_scale
# blocks.24.hook_v_input
# blocks.24.hook_k_input
# blocks.24.hook_q_input
# blocks.24.hook_resid_pre
# blocks.23.hook_resid_post
# blocks.23.hook_mlp_out
# blocks.23.mlp.hook_post
# blocks.23.mlp.hook_pre_linear
# blocks.23.mlp.hook_pre
# blocks.23.ln2.hook_normalized
# blocks.23.ln2.hook_scale
# blocks.23.hook_mlp_in
# blocks.23.hook_resid_mid
# blocks.23.hook_attn_out
# blocks.23.attn.hook_result
# blocks.23.attn.hook_z
# blocks.23.attn.hook_pattern
# blocks.23.attn.hook_attn_scores
# blocks.23.attn.hook_rot_k
# blocks.23.attn.hook_rot_q
# blocks.23.attn.hook_v
# blocks.23.attn.hook_k
# blocks.23.attn.hook_q
# blocks.23.ln1.hook_normalized
# blocks.23.ln1.hook_scale
# blocks.23.hook_v_input
# blocks.23.hook_k_input
# blocks.23.hook_q_input
# blocks.23.hook_resid_pre
# blocks.22.hook_resid_post
# blocks.22.hook_mlp_out
# blocks.22.mlp.hook_post
# blocks.22.mlp.hook_pre_linear
# blocks.22.mlp.hook_pre
# blocks.22.ln2.hook_normalized
# blocks.22.ln2.hook_scale
# blocks.22.hook_mlp_in
# blocks.22.hook_resid_mid
# blocks.22.hook_attn_out
# blocks.22.attn.hook_result
# blocks.22.attn.hook_z
# blocks.22.attn.hook_pattern
# blocks.22.attn.hook_attn_scores
# blocks.22.attn.hook_rot_k
# blocks.22.attn.hook_rot_q
# blocks.22.attn.hook_v
# blocks.22.attn.hook_k
# blocks.22.attn.hook_q
# blocks.22.ln1.hook_normalized
# blocks.22.ln1.hook_scale
# blocks.22.hook_v_input
# blocks.22.hook_k_input
# blocks.22.hook_q_input
# blocks.22.hook_resid_pre
# blocks.21.hook_resid_post
# blocks.21.hook_mlp_out
# blocks.21.mlp.hook_post
# blocks.21.mlp.hook_pre_linear
# blocks.21.mlp.hook_pre
# blocks.21.ln2.hook_normalized
# blocks.21.ln2.hook_scale
# blocks.21.hook_mlp_in
# blocks.21.hook_resid_mid
# blocks.21.hook_attn_out
# blocks.21.attn.hook_result
# blocks.21.attn.hook_z
# blocks.21.attn.hook_pattern
# blocks.21.attn.hook_attn_scores
# blocks.21.attn.hook_rot_k
# blocks.21.attn.hook_rot_q
# blocks.21.attn.hook_v
# blocks.21.attn.hook_k
# blocks.21.attn.hook_q
# blocks.21.ln1.hook_normalized
# blocks.21.ln1.hook_scale
# blocks.21.hook_v_input
# blocks.21.hook_k_input
# blocks.21.hook_q_input
# blocks.21.hook_resid_pre
# blocks.20.hook_resid_post
# blocks.20.hook_mlp_out
# blocks.20.mlp.hook_post
# blocks.20.mlp.hook_pre_linear
# blocks.20.mlp.hook_pre
# blocks.20.ln2.hook_normalized
# blocks.20.ln2.hook_scale
# blocks.20.hook_mlp_in
# blocks.20.hook_resid_mid
# blocks.20.hook_attn_out
# blocks.20.attn.hook_result
# blocks.20.attn.hook_z
# blocks.20.attn.hook_pattern
# blocks.20.attn.hook_attn_scores
# blocks.20.attn.hook_rot_k
# blocks.20.attn.hook_rot_q
# blocks.20.attn.hook_v
# blocks.20.attn.hook_k
# blocks.20.attn.hook_q
# blocks.20.ln1.hook_normalized
# blocks.20.ln1.hook_scale
# blocks.20.hook_v_input
# blocks.20.hook_k_input
# blocks.20.hook_q_input
# blocks.20.hook_resid_pre
# blocks.19.hook_resid_post
# blocks.19.hook_mlp_out
# blocks.19.mlp.hook_post
# blocks.19.mlp.hook_pre_linear
# blocks.19.mlp.hook_pre
# blocks.19.ln2.hook_normalized
# blocks.19.ln2.hook_scale
# blocks.19.hook_mlp_in
# blocks.19.hook_resid_mid
# blocks.19.hook_attn_out
# blocks.19.attn.hook_result
# blocks.19.attn.hook_z
# blocks.19.attn.hook_pattern
# blocks.19.attn.hook_attn_scores
# blocks.19.attn.hook_rot_k
# blocks.19.attn.hook_rot_q
# blocks.19.attn.hook_v
# blocks.19.attn.hook_k
# blocks.19.attn.hook_q
# blocks.19.ln1.hook_normalized
# blocks.19.ln1.hook_scale
# blocks.19.hook_v_input
# blocks.19.hook_k_input
# blocks.19.hook_q_input
# blocks.19.hook_resid_pre
# blocks.18.hook_resid_post
# blocks.18.hook_mlp_out
# blocks.18.mlp.hook_post
# blocks.18.mlp.hook_pre_linear
# blocks.18.mlp.hook_pre
# blocks.18.ln2.hook_normalized
# blocks.18.ln2.hook_scale
# blocks.18.hook_mlp_in
# blocks.18.hook_resid_mid
# blocks.18.hook_attn_out
# blocks.18.attn.hook_result
# blocks.18.attn.hook_z
# blocks.18.attn.hook_pattern
# blocks.18.attn.hook_attn_scores
# blocks.18.attn.hook_rot_k
# blocks.18.attn.hook_rot_q
# blocks.18.attn.hook_v
# blocks.18.attn.hook_k
# blocks.18.attn.hook_q
# blocks.18.ln1.hook_normalized
# blocks.18.ln1.hook_scale
# blocks.18.hook_v_input
# blocks.18.hook_k_input
# blocks.18.hook_q_input
# blocks.18.hook_resid_pre
# blocks.17.hook_resid_post
# blocks.17.hook_mlp_out
# blocks.17.mlp.hook_post
# blocks.17.mlp.hook_pre_linear
# blocks.17.mlp.hook_pre
# blocks.17.ln2.hook_normalized
# blocks.17.ln2.hook_scale
# blocks.17.hook_mlp_in
# blocks.17.hook_resid_mid
# blocks.17.hook_attn_out
# blocks.17.attn.hook_result
# blocks.17.attn.hook_z
# blocks.17.attn.hook_pattern
# blocks.17.attn.hook_attn_scores
# blocks.17.attn.hook_rot_k
# blocks.17.attn.hook_rot_q
# blocks.17.attn.hook_v
# blocks.17.attn.hook_k
# blocks.17.attn.hook_q
# blocks.17.ln1.hook_normalized
# blocks.17.ln1.hook_scale
# blocks.17.hook_v_input
# blocks.17.hook_k_input
# blocks.17.hook_q_input
# blocks.17.hook_resid_pre
# blocks.16.hook_resid_post
# blocks.16.hook_mlp_out
# blocks.16.mlp.hook_post
# blocks.16.mlp.hook_pre_linear
# blocks.16.mlp.hook_pre
# blocks.16.ln2.hook_normalized
# blocks.16.ln2.hook_scale
# blocks.16.hook_mlp_in
# blocks.16.hook_resid_mid
# blocks.16.hook_attn_out
# blocks.16.attn.hook_result
# blocks.16.attn.hook_z
# blocks.16.attn.hook_pattern
# blocks.16.attn.hook_attn_scores
# blocks.16.attn.hook_rot_k
# blocks.16.attn.hook_rot_q
# blocks.16.attn.hook_v
# blocks.16.attn.hook_k
# blocks.16.attn.hook_q
# blocks.16.ln1.hook_normalized
# blocks.16.ln1.hook_scale
# blocks.16.hook_v_input
# blocks.16.hook_k_input
# blocks.16.hook_q_input
# blocks.16.hook_resid_pre
# blocks.15.hook_resid_post
# blocks.15.hook_mlp_out
# blocks.15.mlp.hook_post
# blocks.15.mlp.hook_pre_linear
# blocks.15.mlp.hook_pre
# blocks.15.ln2.hook_normalized
# blocks.15.ln2.hook_scale
# blocks.15.hook_mlp_in
# blocks.15.hook_resid_mid
# blocks.15.hook_attn_out
# blocks.15.attn.hook_result
# blocks.15.attn.hook_z
# blocks.15.attn.hook_pattern
# blocks.15.attn.hook_attn_scores
# blocks.15.attn.hook_rot_k
# blocks.15.attn.hook_rot_q
# blocks.15.attn.hook_v
# blocks.15.attn.hook_k
# blocks.15.attn.hook_q
# blocks.15.ln1.hook_normalized
# blocks.15.ln1.hook_scale
# blocks.15.hook_v_input
# blocks.15.hook_k_input
# blocks.15.hook_q_input
# blocks.15.hook_resid_pre
# blocks.14.hook_resid_post
# blocks.14.hook_mlp_out
# blocks.14.mlp.hook_post
# blocks.14.mlp.hook_pre_linear
# blocks.14.mlp.hook_pre
# blocks.14.ln2.hook_normalized
# blocks.14.ln2.hook_scale
# blocks.14.hook_mlp_in
# blocks.14.hook_resid_mid
# blocks.14.hook_attn_out
# blocks.14.attn.hook_result
# blocks.14.attn.hook_z
# blocks.14.attn.hook_pattern
# blocks.14.attn.hook_attn_scores
# blocks.14.attn.hook_rot_k
# blocks.14.attn.hook_rot_q
# blocks.14.attn.hook_v
# blocks.14.attn.hook_k
# blocks.14.attn.hook_q
# blocks.14.ln1.hook_normalized
# blocks.14.ln1.hook_scale
# blocks.14.hook_v_input
# blocks.14.hook_k_input
# blocks.14.hook_q_input
# blocks.14.hook_resid_pre
# blocks.13.hook_resid_post
# blocks.13.hook_mlp_out
# blocks.13.mlp.hook_post
# blocks.13.mlp.hook_pre_linear
# blocks.13.mlp.hook_pre
# blocks.13.ln2.hook_normalized
# blocks.13.ln2.hook_scale
# blocks.13.hook_mlp_in
# blocks.13.hook_resid_mid
# blocks.13.hook_attn_out
# blocks.13.attn.hook_result
# blocks.13.attn.hook_z
# blocks.13.attn.hook_pattern
# blocks.13.attn.hook_attn_scores
# blocks.13.attn.hook_rot_k
# blocks.13.attn.hook_rot_q
# blocks.13.attn.hook_v
# blocks.13.attn.hook_k
# blocks.13.attn.hook_q
# blocks.13.ln1.hook_normalized
# blocks.13.ln1.hook_scale
# blocks.13.hook_v_input
# blocks.13.hook_k_input
# blocks.13.hook_q_input
# blocks.13.hook_resid_pre
# blocks.12.hook_resid_post
# blocks.12.hook_mlp_out
# blocks.12.mlp.hook_post
# blocks.12.mlp.hook_pre_linear
# blocks.12.mlp.hook_pre
# blocks.12.ln2.hook_normalized
# blocks.12.ln2.hook_scale
# blocks.12.hook_mlp_in
# blocks.12.hook_resid_mid
# blocks.12.hook_attn_out
# blocks.12.attn.hook_result
# blocks.12.attn.hook_z
# blocks.12.attn.hook_pattern
# blocks.12.attn.hook_attn_scores
# blocks.12.attn.hook_rot_k
# blocks.12.attn.hook_rot_q
# blocks.12.attn.hook_v
# blocks.12.attn.hook_k
# blocks.12.attn.hook_q
# blocks.12.ln1.hook_normalized
# blocks.12.ln1.hook_scale
# blocks.12.hook_v_input
# blocks.12.hook_k_input
# blocks.12.hook_q_input
# blocks.12.hook_resid_pre
# blocks.11.hook_resid_post
# blocks.11.hook_mlp_out
# blocks.11.mlp.hook_post
# blocks.11.mlp.hook_pre_linear
# blocks.11.mlp.hook_pre
# blocks.11.ln2.hook_normalized
# blocks.11.ln2.hook_scale
# blocks.11.hook_mlp_in
# blocks.11.hook_resid_mid
# blocks.11.hook_attn_out
# blocks.11.attn.hook_result
# blocks.11.attn.hook_z
# blocks.11.attn.hook_pattern
# blocks.11.attn.hook_attn_scores
# blocks.11.attn.hook_rot_k
# blocks.11.attn.hook_rot_q
# blocks.11.attn.hook_v
# blocks.11.attn.hook_k
# blocks.11.attn.hook_q
# blocks.11.ln1.hook_normalized
# blocks.11.ln1.hook_scale
# blocks.11.hook_v_input
# blocks.11.hook_k_input
# blocks.11.hook_q_input
# blocks.11.hook_resid_pre
# blocks.10.hook_resid_post
# blocks.10.hook_mlp_out
# blocks.10.mlp.hook_post
# blocks.10.mlp.hook_pre_linear
# blocks.10.mlp.hook_pre
# blocks.10.ln2.hook_normalized
# blocks.10.ln2.hook_scale
# blocks.10.hook_mlp_in
# blocks.10.hook_resid_mid
# blocks.10.hook_attn_out
# blocks.10.attn.hook_result
# blocks.10.attn.hook_z
# blocks.10.attn.hook_pattern
# blocks.10.attn.hook_attn_scores
# blocks.10.attn.hook_rot_k
# blocks.10.attn.hook_rot_q
# blocks.10.attn.hook_v
# blocks.10.attn.hook_k
# blocks.10.attn.hook_q
# blocks.10.ln1.hook_normalized
# blocks.10.ln1.hook_scale
# blocks.10.hook_v_input
# blocks.10.hook_k_input
# blocks.10.hook_q_input
# blocks.10.hook_resid_pre
# blocks.9.hook_resid_post
# blocks.9.hook_mlp_out
# blocks.9.mlp.hook_post
# blocks.9.mlp.hook_pre_linear
# blocks.9.mlp.hook_pre
# blocks.9.ln2.hook_normalized
# blocks.9.ln2.hook_scale
# blocks.9.hook_mlp_in
# blocks.9.hook_resid_mid
# blocks.9.hook_attn_out
# blocks.9.attn.hook_result
# blocks.9.attn.hook_z
# blocks.9.attn.hook_pattern
# blocks.9.attn.hook_attn_scores
# blocks.9.attn.hook_rot_k
# blocks.9.attn.hook_rot_q
# blocks.9.attn.hook_v
# blocks.9.attn.hook_k
# blocks.9.attn.hook_q
# blocks.9.ln1.hook_normalized
# blocks.9.ln1.hook_scale
# blocks.9.hook_v_input
# blocks.9.hook_k_input
# blocks.9.hook_q_input
# blocks.9.hook_resid_pre
# blocks.8.hook_resid_post
# blocks.8.hook_mlp_out
# blocks.8.mlp.hook_post
# blocks.8.mlp.hook_pre_linear
# blocks.8.mlp.hook_pre
# blocks.8.ln2.hook_normalized
# blocks.8.ln2.hook_scale
# blocks.8.hook_mlp_in
# blocks.8.hook_resid_mid
# blocks.8.hook_attn_out
# blocks.8.attn.hook_result
# blocks.8.attn.hook_z
# blocks.8.attn.hook_pattern
# blocks.8.attn.hook_attn_scores
# blocks.8.attn.hook_rot_k
# blocks.8.attn.hook_rot_q
# blocks.8.attn.hook_v
# blocks.8.attn.hook_k
# blocks.8.attn.hook_q
# blocks.8.ln1.hook_normalized
# blocks.8.ln1.hook_scale
# blocks.8.hook_v_input
# blocks.8.hook_k_input
# blocks.8.hook_q_input
# blocks.8.hook_resid_pre
# blocks.7.hook_resid_post
# blocks.7.hook_mlp_out
# blocks.7.mlp.hook_post
# blocks.7.mlp.hook_pre_linear
# blocks.7.mlp.hook_pre
# blocks.7.ln2.hook_normalized
# blocks.7.ln2.hook_scale
# blocks.7.hook_mlp_in
# blocks.7.hook_resid_mid
# blocks.7.hook_attn_out
# blocks.7.attn.hook_result
# blocks.7.attn.hook_z
# blocks.7.attn.hook_pattern
# blocks.7.attn.hook_attn_scores
# blocks.7.attn.hook_rot_k
# blocks.7.attn.hook_rot_q
# blocks.7.attn.hook_v
# blocks.7.attn.hook_k
# blocks.7.attn.hook_q
# blocks.7.ln1.hook_normalized
# blocks.7.ln1.hook_scale
# blocks.7.hook_v_input
# blocks.7.hook_k_input
# blocks.7.hook_q_input
# blocks.7.hook_resid_pre
# blocks.6.hook_resid_post
# blocks.6.hook_mlp_out
# blocks.6.mlp.hook_post
# blocks.6.mlp.hook_pre_linear
# blocks.6.mlp.hook_pre
# blocks.6.ln2.hook_normalized
# blocks.6.ln2.hook_scale
# blocks.6.hook_mlp_in
# blocks.6.hook_resid_mid
# blocks.6.hook_attn_out
# blocks.6.attn.hook_result
# blocks.6.attn.hook_z
# blocks.6.attn.hook_pattern
# blocks.6.attn.hook_attn_scores
# blocks.6.attn.hook_rot_k
# blocks.6.attn.hook_rot_q
# blocks.6.attn.hook_v
# blocks.6.attn.hook_k
# blocks.6.attn.hook_q
# blocks.6.ln1.hook_normalized
# blocks.6.ln1.hook_scale
# blocks.6.hook_v_input
# blocks.6.hook_k_input
# blocks.6.hook_q_input
# blocks.6.hook_resid_pre
# blocks.5.hook_resid_post
# blocks.5.hook_mlp_out
# blocks.5.mlp.hook_post
# blocks.5.mlp.hook_pre_linear
# blocks.5.mlp.hook_pre
# blocks.5.ln2.hook_normalized
# blocks.5.ln2.hook_scale
# blocks.5.hook_mlp_in
# blocks.5.hook_resid_mid
# blocks.5.hook_attn_out
# blocks.5.attn.hook_result
# blocks.5.attn.hook_z
# blocks.5.attn.hook_pattern
# blocks.5.attn.hook_attn_scores
# blocks.5.attn.hook_rot_k
# blocks.5.attn.hook_rot_q
# blocks.5.attn.hook_v
# blocks.5.attn.hook_k
# blocks.5.attn.hook_q
# blocks.5.ln1.hook_normalized
# blocks.5.ln1.hook_scale
# blocks.5.hook_v_input
# blocks.5.hook_k_input
# blocks.5.hook_q_input
# blocks.5.hook_resid_pre
# blocks.4.hook_resid_post
# blocks.4.hook_mlp_out
# blocks.4.mlp.hook_post
# blocks.4.mlp.hook_pre_linear
# blocks.4.mlp.hook_pre
# blocks.4.ln2.hook_normalized
# blocks.4.ln2.hook_scale
# blocks.4.hook_mlp_in
# blocks.4.hook_resid_mid
# blocks.4.hook_attn_out
# blocks.4.attn.hook_result
# blocks.4.attn.hook_z
# blocks.4.attn.hook_pattern
# blocks.4.attn.hook_attn_scores
# blocks.4.attn.hook_rot_k
# blocks.4.attn.hook_rot_q
# blocks.4.attn.hook_v
# blocks.4.attn.hook_k
# blocks.4.attn.hook_q
# blocks.4.ln1.hook_normalized
# blocks.4.ln1.hook_scale
# blocks.4.hook_v_input
# blocks.4.hook_k_input
# blocks.4.hook_q_input
# blocks.4.hook_resid_pre
# blocks.3.hook_resid_post
# blocks.3.hook_mlp_out
# blocks.3.mlp.hook_post
# blocks.3.mlp.hook_pre_linear
# blocks.3.mlp.hook_pre
# blocks.3.ln2.hook_normalized
# blocks.3.ln2.hook_scale
# blocks.3.hook_mlp_in
# blocks.3.hook_resid_mid
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_rot_k
# blocks.3.attn.hook_rot_q
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_mlp_out
# blocks.2.mlp.hook_post
# blocks.2.mlp.hook_pre_linear
# blocks.2.mlp.hook_pre
# blocks.2.ln2.hook_normalized
# blocks.2.ln2.hook_scale
# blocks.2.hook_mlp_in
# blocks.2.hook_resid_mid
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_rot_k
# blocks.2.attn.hook_rot_q
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_mlp_out
# blocks.1.mlp.hook_post
# blocks.1.mlp.hook_pre_linear
# blocks.1.mlp.hook_pre
# blocks.1.ln2.hook_normalized
# blocks.1.ln2.hook_scale
# blocks.1.hook_mlp_in
# blocks.1.hook_resid_mid
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_rot_k
# blocks.1.attn.hook_rot_q
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_mlp_out
# blocks.0.mlp.hook_post
# blocks.0.mlp.hook_pre_linear
# blocks.0.mlp.hook_pre
# blocks.0.ln2.hook_normalized
# blocks.0.ln2.hook_scale
# blocks.0.hook_mlp_in
# blocks.0.hook_resid_mid
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_rot_k
# blocks.0.attn.hook_rot_q
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.31.hook_resid_post, [:])
# Adding sender hooks...
# Done corrupting things
#   0%|          | 0/4 [10:24<?, ?it/s]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3548, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_713472/1894408772.py", line 17, in <module>
#     pruned_heads, num_passes, pruned_attrs = acdcpp_exp.run()
#                                              ^^^^^^^^^^^^^^^^
#   File "/home/obalcells/acdcpp/minimal_eap/../ACDCPPExperiment.py", line 134, in run
#     exp = self.setup_exp(threshold)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/obalcells/acdcpp/minimal_eap/../ACDCPPExperiment.py", line 74, in setup_exp
#     exp = TLACDCExperiment(
#           ^^^^^^^^^^^^^^^^^
#   File "/home/obalcells/acdcpp/minimal_eap/../Automatic-Circuit-Discovery/acdc/TLACDCExperiment.py", line 141, in __init__
#     self.setup_corrupted_cache()
#   File "/home/obalcells/acdcpp/minimal_eap/../Automatic-Circuit-Discovery/acdc/TLACDCExperiment.py", line 454, in setup_corrupted_cache
#   File "/home/obalcells/acdcpp/minimal_eap/../Automatic-Circuit-Discovery/acdc/global_cache.py", line 48, in to
#     cache[k].to(device) #  = cache[name].to(device)
#     ^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2142, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/local/home/obalcells/miniforge3/envs/jailbreak/lib/python3.11/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
clear_memory()
# Out:
# Cleared 0 MB. Current CUDA memory is 13459 MB.

# %%
THRESHOLDS = np.array([0.03, 0.01, 0.1, 1.0])
RUN_NAME = 'refusal_experiment'

acdcpp_exp = ACDCPPExperiment(tl_model,
                              harmful_dataset.prompt_toks,
                              harmless_dataset.prompt_toks,
                              metric,
                              metric,
                              THRESHOLDS,
                              run_name=RUN_NAME,
                              verbose=True,
                              attr_absolute_val=True,
                              save_graphs_after=0,
                              pruning_mode="edge",
                              no_pruned_nodes_attr=1
                             )
pruned_heads, num_passes, pruned_attrs = acdcpp_exp.run()
# Out:
# Set up model hooks
#   0%|          | 0/4 [00:00<?, ?it/s]
# Setting up experiment...
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# dict_keys(['blocks.31.hook_resid_post', 'blocks.31.hook_mlp_out', 'blocks.31.hook_mlp_in', 'blocks.31.attn.hook_result', 'blocks.31.attn.hook_q', 'blocks.31.hook_q_input', 'blocks.31.attn.hook_k', 'blocks.31.hook_k_input', 'blocks.31.attn.hook_v', 'blocks.31.hook_v_input', 'blocks.30.hook_mlp_out', 'blocks.30.hook_mlp_in', 'blocks.30.attn.hook_result', 'blocks.30.attn.hook_q', 'blocks.30.hook_q_input', 'blocks.30.attn.hook_k', 'blocks.30.hook_k_input', 'blocks.30.attn.hook_v', 'blocks.30.hook_v_input', 'blocks.29.hook_mlp_out', 'blocks.29.hook_mlp_in', 'blocks.29.attn.hook_result', 'blocks.29.attn.hook_q', 'blocks.29.hook_q_input', 'blocks.29.attn.hook_k', 'blocks.29.hook_k_input', 'blocks.29.attn.hook_v', 'blocks.29.hook_v_input', 'blocks.28.hook_mlp_out', 'blocks.28.hook_mlp_in', 'blocks.28.attn.hook_result', 'blocks.28.attn.hook_q', 'blocks.28.hook_q_input', 'blocks.28.attn.hook_k', 'blocks.28.hook_k_input', 'blocks.28.attn.hook_v', 'blocks.28.hook_v_input', 'blocks.27.hook_mlp_out', 'blocks.27.hook_mlp_in', 'blocks.27.attn.hook_result', 'blocks.27.attn.hook_q', 'blocks.27.hook_q_input', 'blocks.27.attn.hook_k', 'blocks.27.hook_k_input', 'blocks.27.attn.hook_v', 'blocks.27.hook_v_input', 'blocks.26.hook_mlp_out', 'blocks.26.hook_mlp_in', 'blocks.26.attn.hook_result', 'blocks.26.attn.hook_q', 'blocks.26.hook_q_input', 'blocks.26.attn.hook_k', 'blocks.26.hook_k_input', 'blocks.26.attn.hook_v', 'blocks.26.hook_v_input', 'blocks.25.hook_mlp_out', 'blocks.25.hook_mlp_in', 'blocks.25.attn.hook_result', 'blocks.25.attn.hook_q', 'blocks.25.hook_q_input', 'blocks.25.attn.hook_k', 'blocks.25.hook_k_input', 'blocks.25.attn.hook_v', 'blocks.25.hook_v_input', 'blocks.24.hook_mlp_out', 'blocks.24.hook_mlp_in', 'blocks.24.attn.hook_result', 'blocks.24.attn.hook_q', 'blocks.24.hook_q_input', 'blocks.24.attn.hook_k', 'blocks.24.hook_k_input', 'blocks.24.attn.hook_v', 'blocks.24.hook_v_input', 'blocks.23.hook_mlp_out', 'blocks.23.hook_mlp_in', 'blocks.23.attn.hook_result', 'blocks.23.attn.hook_q', 'blocks.23.hook_q_input', 'blocks.23.attn.hook_k', 'blocks.23.hook_k_input', 'blocks.23.attn.hook_v', 'blocks.23.hook_v_input', 'blocks.22.hook_mlp_out', 'blocks.22.hook_mlp_in', 'blocks.22.attn.hook_result', 'blocks.22.attn.hook_q', 'blocks.22.hook_q_input', 'blocks.22.attn.hook_k', 'blocks.22.hook_k_input', 'blocks.22.attn.hook_v', 'blocks.22.hook_v_input', 'blocks.21.hook_mlp_out', 'blocks.21.hook_mlp_in', 'blocks.21.attn.hook_result', 'blocks.21.attn.hook_q', 'blocks.21.hook_q_input', 'blocks.21.attn.hook_k', 'blocks.21.hook_k_input', 'blocks.21.attn.hook_v', 'blocks.21.hook_v_input', 'blocks.20.hook_mlp_out', 'blocks.20.hook_mlp_in', 'blocks.20.attn.hook_result', 'blocks.20.attn.hook_q', 'blocks.20.hook_q_input', 'blocks.20.attn.hook_k', 'blocks.20.hook_k_input', 'blocks.20.attn.hook_v', 'blocks.20.hook_v_input', 'blocks.19.hook_mlp_out', 'blocks.19.hook_mlp_in', 'blocks.19.attn.hook_result', 'blocks.19.attn.hook_q', 'blocks.19.hook_q_input', 'blocks.19.attn.hook_k', 'blocks.19.hook_k_input', 'blocks.19.attn.hook_v', 'blocks.19.hook_v_input', 'blocks.18.hook_mlp_out', 'blocks.18.hook_mlp_in', 'blocks.18.attn.hook_result', 'blocks.18.attn.hook_q', 'blocks.18.hook_q_input', 'blocks.18.attn.hook_k', 'blocks.18.hook_k_input', 'blocks.18.attn.hook_v', 'blocks.18.hook_v_input', 'blocks.17.hook_mlp_out', 'blocks.17.hook_mlp_in', 'blocks.17.attn.hook_result', 'blocks.17.attn.hook_q', 'blocks.17.hook_q_input', 'blocks.17.attn.hook_k', 'blocks.17.hook_k_input', 'blocks.17.attn.hook_v', 'blocks.17.hook_v_input', 'blocks.16.hook_mlp_out', 'blocks.16.hook_mlp_in', 'blocks.16.attn.hook_result', 'blocks.16.attn.hook_q', 'blocks.16.hook_q_input', 'blocks.16.attn.hook_k', 'blocks.16.hook_k_input', 'blocks.16.attn.hook_v', 'blocks.16.hook_v_input', 'blocks.15.hook_mlp_out', 'blocks.15.hook_mlp_in', 'blocks.15.attn.hook_result', 'blocks.15.attn.hook_q', 'blocks.15.hook_q_input', 'blocks.15.attn.hook_k', 'blocks.15.hook_k_input', 'blocks.15.attn.hook_v', 'blocks. ...
# ln_final.hook_normalized
# ln_final.hook_scale
# blocks.31.hook_resid_post
# blocks.31.hook_mlp_out
# blocks.31.mlp.hook_post
# blocks.31.mlp.hook_pre_linear
# blocks.31.mlp.hook_pre
# blocks.31.ln2.hook_normalized
# blocks.31.ln2.hook_scale
# blocks.31.hook_mlp_in
# blocks.31.hook_resid_mid
# blocks.31.hook_attn_out
# blocks.31.attn.hook_result
# blocks.31.attn.hook_z
# blocks.31.attn.hook_pattern
# blocks.31.attn.hook_attn_scores
# blocks.31.attn.hook_rot_k
# blocks.31.attn.hook_rot_q
# blocks.31.attn.hook_v
# blocks.31.attn.hook_k
# blocks.31.attn.hook_q
# blocks.31.ln1.hook_normalized
# blocks.31.ln1.hook_scale
# blocks.31.hook_v_input
# blocks.31.hook_k_input
# blocks.31.hook_q_input
# blocks.31.hook_resid_pre
# blocks.30.hook_resid_post
# blocks.30.hook_mlp_out
# blocks.30.mlp.hook_post
# blocks.30.mlp.hook_pre_linear
# blocks.30.mlp.hook_pre
# blocks.30.ln2.hook_normalized
# blocks.30.ln2.hook_scale
# blocks.30.hook_mlp_in
# blocks.30.hook_resid_mid
# blocks.30.hook_attn_out
# blocks.30.attn.hook_result
# blocks.30.attn.hook_z
# blocks.30.attn.hook_pattern
# blocks.30.attn.hook_attn_scores
# blocks.30.attn.hook_rot_k
# blocks.30.attn.hook_rot_q
# blocks.30.attn.hook_v
# blocks.30.attn.hook_k
# blocks.30.attn.hook_q
# blocks.30.ln1.hook_normalized
# blocks.30.ln1.hook_scale
# blocks.30.hook_v_input
# blocks.30.hook_k_input
# blocks.30.hook_q_input
# blocks.30.hook_resid_pre
# blocks.29.hook_resid_post
# blocks.29.hook_mlp_out
# blocks.29.mlp.hook_post
# blocks.29.mlp.hook_pre_linear
# blocks.29.mlp.hook_pre
# blocks.29.ln2.hook_normalized
# blocks.29.ln2.hook_scale
# blocks.29.hook_mlp_in
# blocks.29.hook_resid_mid
# blocks.29.hook_attn_out
# blocks.29.attn.hook_result
# blocks.29.attn.hook_z
# blocks.29.attn.hook_pattern
# blocks.29.attn.hook_attn_scores
# blocks.29.attn.hook_rot_k
# blocks.29.attn.hook_rot_q
# blocks.29.attn.hook_v
# blocks.29.attn.hook_k
# blocks.29.attn.hook_q
# blocks.29.ln1.hook_normalized
# blocks.29.ln1.hook_scale
# blocks.29.hook_v_input
# blocks.29.hook_k_input
# blocks.29.hook_q_input
# blocks.29.hook_resid_pre
# blocks.28.hook_resid_post
# blocks.28.hook_mlp_out
# blocks.28.mlp.hook_post
# blocks.28.mlp.hook_pre_linear
# blocks.28.mlp.hook_pre
# blocks.28.ln2.hook_normalized
# blocks.28.ln2.hook_scale
# blocks.28.hook_mlp_in
# blocks.28.hook_resid_mid
# blocks.28.hook_attn_out
# blocks.28.attn.hook_result
# blocks.28.attn.hook_z
# blocks.28.attn.hook_pattern
# blocks.28.attn.hook_attn_scores
# blocks.28.attn.hook_rot_k
# blocks.28.attn.hook_rot_q
# blocks.28.attn.hook_v
# blocks.28.attn.hook_k
# blocks.28.attn.hook_q
# blocks.28.ln1.hook_normalized
# blocks.28.ln1.hook_scale
# blocks.28.hook_v_input
# blocks.28.hook_k_input
# blocks.28.hook_q_input
# blocks.28.hook_resid_pre
# blocks.27.hook_resid_post
# blocks.27.hook_mlp_out
# blocks.27.mlp.hook_post
# blocks.27.mlp.hook_pre_linear
# blocks.27.mlp.hook_pre
# blocks.27.ln2.hook_normalized
# blocks.27.ln2.hook_scale
# blocks.27.hook_mlp_in
# blocks.27.hook_resid_mid
# blocks.27.hook_attn_out
# blocks.27.attn.hook_result
# blocks.27.attn.hook_z
# blocks.27.attn.hook_pattern
# blocks.27.attn.hook_attn_scores
# blocks.27.attn.hook_rot_k
# blocks.27.attn.hook_rot_q
# blocks.27.attn.hook_v
# blocks.27.attn.hook_k
# blocks.27.attn.hook_q
# blocks.27.ln1.hook_normalized
# blocks.27.ln1.hook_scale
# blocks.27.hook_v_input
# blocks.27.hook_k_input
# blocks.27.hook_q_input
# blocks.27.hook_resid_pre
# blocks.26.hook_resid_post
# blocks.26.hook_mlp_out
# blocks.26.mlp.hook_post
# blocks.26.mlp.hook_pre_linear
# blocks.26.mlp.hook_pre
# blocks.26.ln2.hook_normalized
# blocks.26.ln2.hook_scale
# blocks.26.hook_mlp_in
# blocks.26.hook_resid_mid
# blocks.26.hook_attn_out
# blocks.26.attn.hook_result
# blocks.26.attn.hook_z
# blocks.26.attn.hook_pattern
# blocks.26.attn.hook_attn_scores
# blocks.26.attn.hook_rot_k
# blocks.26.attn.hook_rot_q
# blocks.26.attn.hook_v
# blocks.26.attn.hook_k
# blocks.26.attn.hook_q
# blocks.26.ln1.hook_normalized
# blocks.26.ln1.hook_scale
# blocks.26.hook_v_input
# blocks.26.hook_k_input
# blocks.26.hook_q_input
# blocks.26.hook_resid_pre
# blocks.25.hook_resid_post
# blocks.25.hook_mlp_out
# blocks.25.mlp.hook_post
# blocks.25.mlp.hook_pre_linear
# blocks.25.mlp.hook_pre
# blocks.25.ln2.hook_normalized
# blocks.25.ln2.hook_scale
# blocks.25.hook_mlp_in
# blocks.25.hook_resid_mid
# blocks.25.hook_attn_out
# blocks.25.attn.hook_result
# blocks.25.attn.hook_z
# blocks.25.attn.hook_pattern
# blocks.25.attn.hook_attn_scores
# blocks.25.attn.hook_rot_k
# blocks.25.attn.hook_rot_q
# blocks.25.attn.hook_v
# blocks.25.attn.hook_k
# blocks.25.attn.hook_q
# blocks.25.ln1.hook_normalized
# blocks.25.ln1.hook_scale
# blocks.25.hook_v_input
# blocks.25.hook_k_input
# blocks.25.hook_q_input
# blocks.25.hook_resid_pre
# blocks.24.hook_resid_post
# blocks.24.hook_mlp_out
# blocks.24.mlp.hook_post
# blocks.24.mlp.hook_pre_linear
# blocks.24.mlp.hook_pre
# blocks.24.ln2.hook_normalized
# blocks.24.ln2.hook_scale
# blocks.24.hook_mlp_in
# blocks.24.hook_resid_mid
# blocks.24.hook_attn_out
# blocks.24.attn.hook_result
# blocks.24.attn.hook_z
# blocks.24.attn.hook_pattern
# blocks.24.attn.hook_attn_scores
# blocks.24.attn.hook_rot_k
# blocks.24.attn.hook_rot_q
# blocks.24.attn.hook_v
# blocks.24.attn.hook_k
# blocks.24.attn.hook_q
# blocks.24.ln1.hook_normalized
# blocks.24.ln1.hook_scale
# blocks.24.hook_v_input
# blocks.24.hook_k_input
# blocks.24.hook_q_input
# blocks.24.hook_resid_pre
# blocks.23.hook_resid_post
# blocks.23.hook_mlp_out
# blocks.23.mlp.hook_post
# blocks.23.mlp.hook_pre_linear
# blocks.23.mlp.hook_pre
# blocks.23.ln2.hook_normalized
# blocks.23.ln2.hook_scale
# blocks.23.hook_mlp_in
# blocks.23.hook_resid_mid
# blocks.23.hook_attn_out
# blocks.23.attn.hook_result
# blocks.23.attn.hook_z
# blocks.23.attn.hook_pattern
# blocks.23.attn.hook_attn_scores
# blocks.23.attn.hook_rot_k
# blocks.23.attn.hook_rot_q
# blocks.23.attn.hook_v
# blocks.23.attn.hook_k
# blocks.23.attn.hook_q
# blocks.23.ln1.hook_normalized
# blocks.23.ln1.hook_scale
# blocks.23.hook_v_input
# blocks.23.hook_k_input
# blocks.23.hook_q_input
# blocks.23.hook_resid_pre
# blocks.22.hook_resid_post
# blocks.22.hook_mlp_out
# blocks.22.mlp.hook_post
# blocks.22.mlp.hook_pre_linear
# blocks.22.mlp.hook_pre
# blocks.22.ln2.hook_normalized
# blocks.22.ln2.hook_scale
# blocks.22.hook_mlp_in
# blocks.22.hook_resid_mid
# blocks.22.hook_attn_out
# blocks.22.attn.hook_result
# blocks.22.attn.hook_z
# blocks.22.attn.hook_pattern
# blocks.22.attn.hook_attn_scores
# blocks.22.attn.hook_rot_k
# blocks.22.attn.hook_rot_q
# blocks.22.attn.hook_v
# blocks.22.attn.hook_k
# blocks.22.attn.hook_q
# blocks.22.ln1.hook_normalized
# blocks.22.ln1.hook_scale
# blocks.22.hook_v_input
# blocks.22.hook_k_input
# blocks.22.hook_q_input
# blocks.22.hook_resid_pre
# blocks.21.hook_resid_post
# blocks.21.hook_mlp_out
# blocks.21.mlp.hook_post
# blocks.21.mlp.hook_pre_linear
# blocks.21.mlp.hook_pre
# blocks.21.ln2.hook_normalized
# blocks.21.ln2.hook_scale
# blocks.21.hook_mlp_in
# blocks.21.hook_resid_mid
# blocks.21.hook_attn_out
# blocks.21.attn.hook_result
# blocks.21.attn.hook_z
# blocks.21.attn.hook_pattern
# blocks.21.attn.hook_attn_scores
# blocks.21.attn.hook_rot_k
# blocks.21.attn.hook_rot_q
# blocks.21.attn.hook_v
# blocks.21.attn.hook_k
# blocks.21.attn.hook_q
# blocks.21.ln1.hook_normalized
# blocks.21.ln1.hook_scale
# blocks.21.hook_v_input
# blocks.21.hook_k_input
# blocks.21.hook_q_input
# blocks.21.hook_resid_pre
# blocks.20.hook_resid_post
# blocks.20.hook_mlp_out
# blocks.20.mlp.hook_post
# blocks.20.mlp.hook_pre_linear
# blocks.20.mlp.hook_pre
# blocks.20.ln2.hook_normalized
# blocks.20.ln2.hook_scale
# blocks.20.hook_mlp_in
# blocks.20.hook_resid_mid
# blocks.20.hook_attn_out
# blocks.20.attn.hook_result
# blocks.20.attn.hook_z
# blocks.20.attn.hook_pattern
# blocks.20.attn.hook_attn_scores
# blocks.20.attn.hook_rot_k
# blocks.20.attn.hook_rot_q
# blocks.20.attn.hook_v
# blocks.20.attn.hook_k
# blocks.20.attn.hook_q
# blocks.20.ln1.hook_normalized
# blocks.20.ln1.hook_scale
# blocks.20.hook_v_input
# blocks.20.hook_k_input
# blocks.20.hook_q_input
# blocks.20.hook_resid_pre
# blocks.19.hook_resid_post
# blocks.19.hook_mlp_out
# blocks.19.mlp.hook_post
# blocks.19.mlp.hook_pre_linear
# blocks.19.mlp.hook_pre
# blocks.19.ln2.hook_normalized
# blocks.19.ln2.hook_scale
# blocks.19.hook_mlp_in
# blocks.19.hook_resid_mid
# blocks.19.hook_attn_out
# blocks.19.attn.hook_result
# blocks.19.attn.hook_z
# blocks.19.attn.hook_pattern
# blocks.19.attn.hook_attn_scores
# blocks.19.attn.hook_rot_k
# blocks.19.attn.hook_rot_q
# blocks.19.attn.hook_v
# blocks.19.attn.hook_k
# blocks.19.attn.hook_q
# blocks.19.ln1.hook_normalized
# blocks.19.ln1.hook_scale
# blocks.19.hook_v_input
# blocks.19.hook_k_input
# blocks.19.hook_q_input
# blocks.19.hook_resid_pre
# blocks.18.hook_resid_post
# blocks.18.hook_mlp_out
# blocks.18.mlp.hook_post
# blocks.18.mlp.hook_pre_linear
# blocks.18.mlp.hook_pre
# blocks.18.ln2.hook_normalized
# blocks.18.ln2.hook_scale
# blocks.18.hook_mlp_in
# blocks.18.hook_resid_mid
# blocks.18.hook_attn_out
# blocks.18.attn.hook_result
# blocks.18.attn.hook_z
# blocks.18.attn.hook_pattern
# blocks.18.attn.hook_attn_scores
# blocks.18.attn.hook_rot_k
# blocks.18.attn.hook_rot_q
# blocks.18.attn.hook_v
# blocks.18.attn.hook_k
# blocks.18.attn.hook_q
# blocks.18.ln1.hook_normalized
# blocks.18.ln1.hook_scale
# blocks.18.hook_v_input
# blocks.18.hook_k_input
# blocks.18.hook_q_input
# blocks.18.hook_resid_pre
# blocks.17.hook_resid_post
# blocks.17.hook_mlp_out
# blocks.17.mlp.hook_post
# blocks.17.mlp.hook_pre_linear
# blocks.17.mlp.hook_pre
# blocks.17.ln2.hook_normalized
# blocks.17.ln2.hook_scale
# blocks.17.hook_mlp_in
# blocks.17.hook_resid_mid
# blocks.17.hook_attn_out
# blocks.17.attn.hook_result
# blocks.17.attn.hook_z
# blocks.17.attn.hook_pattern
# blocks.17.attn.hook_attn_scores
# blocks.17.attn.hook_rot_k
# blocks.17.attn.hook_rot_q
# blocks.17.attn.hook_v
# blocks.17.attn.hook_k
# blocks.17.attn.hook_q
# blocks.17.ln1.hook_normalized
# blocks.17.ln1.hook_scale
# blocks.17.hook_v_input
# blocks.17.hook_k_input
# blocks.17.hook_q_input
# blocks.17.hook_resid_pre
# blocks.16.hook_resid_post
# blocks.16.hook_mlp_out
# blocks.16.mlp.hook_post
# blocks.16.mlp.hook_pre_linear
# blocks.16.mlp.hook_pre
# blocks.16.ln2.hook_normalized
# blocks.16.ln2.hook_scale
# blocks.16.hook_mlp_in
# blocks.16.hook_resid_mid
# blocks.16.hook_attn_out
# blocks.16.attn.hook_result
# blocks.16.attn.hook_z
# blocks.16.attn.hook_pattern
# blocks.16.attn.hook_attn_scores
# blocks.16.attn.hook_rot_k
# blocks.16.attn.hook_rot_q
# blocks.16.attn.hook_v
# blocks.16.attn.hook_k
# blocks.16.attn.hook_q
# blocks.16.ln1.hook_normalized
# blocks.16.ln1.hook_scale
# blocks.16.hook_v_input
# blocks.16.hook_k_input
# blocks.16.hook_q_input
# blocks.16.hook_resid_pre
# blocks.15.hook_resid_post
# blocks.15.hook_mlp_out
# blocks.15.mlp.hook_post
# blocks.15.mlp.hook_pre_linear
# blocks.15.mlp.hook_pre
# blocks.15.ln2.hook_normalized
# blocks.15.ln2.hook_scale
# blocks.15.hook_mlp_in
# blocks.15.hook_resid_mid
# blocks.15.hook_attn_out
# blocks.15.attn.hook_result
# blocks.15.attn.hook_z
# blocks.15.attn.hook_pattern
# blocks.15.attn.hook_attn_scores
# blocks.15.attn.hook_rot_k
# blocks.15.attn.hook_rot_q
# blocks.15.attn.hook_v
# blocks.15.attn.hook_k
# blocks.15.attn.hook_q
# blocks.15.ln1.hook_normalized
# blocks.15.ln1.hook_scale
# blocks.15.hook_v_input
# blocks.15.hook_k_input
# blocks.15.hook_q_input
# blocks.15.hook_resid_pre
# blocks.14.hook_resid_post
# blocks.14.hook_mlp_out
# blocks.14.mlp.hook_post
# blocks.14.mlp.hook_pre_linear
# blocks.14.mlp.hook_pre
# blocks.14.ln2.hook_normalized
# blocks.14.ln2.hook_scale
# blocks.14.hook_mlp_in
# blocks.14.hook_resid_mid
# blocks.14.hook_attn_out
# blocks.14.attn.hook_result
# blocks.14.attn.hook_z
# blocks.14.attn.hook_pattern
# blocks.14.attn.hook_attn_scores
# blocks.14.attn.hook_rot_k
# blocks.14.attn.hook_rot_q
# blocks.14.attn.hook_v
# blocks.14.attn.hook_k
# blocks.14.attn.hook_q
# blocks.14.ln1.hook_normalized
# blocks.14.ln1.hook_scale
# blocks.14.hook_v_input
# blocks.14.hook_k_input
# blocks.14.hook_q_input
# blocks.14.hook_resid_pre
# blocks.13.hook_resid_post
# blocks.13.hook_mlp_out
# blocks.13.mlp.hook_post
# blocks.13.mlp.hook_pre_linear
# blocks.13.mlp.hook_pre
# blocks.13.ln2.hook_normalized
# blocks.13.ln2.hook_scale
# blocks.13.hook_mlp_in
# blocks.13.hook_resid_mid
# blocks.13.hook_attn_out
# blocks.13.attn.hook_result
# blocks.13.attn.hook_z
# blocks.13.attn.hook_pattern
# blocks.13.attn.hook_attn_scores
# blocks.13.attn.hook_rot_k
# blocks.13.attn.hook_rot_q
# blocks.13.attn.hook_v
# blocks.13.attn.hook_k
# blocks.13.attn.hook_q
# blocks.13.ln1.hook_normalized
# blocks.13.ln1.hook_scale
# blocks.13.hook_v_input
# blocks.13.hook_k_input
# blocks.13.hook_q_input
# blocks.13.hook_resid_pre
# blocks.12.hook_resid_post
# blocks.12.hook_mlp_out
# blocks.12.mlp.hook_post
# blocks.12.mlp.hook_pre_linear
# blocks.12.mlp.hook_pre
# blocks.12.ln2.hook_normalized
# blocks.12.ln2.hook_scale
# blocks.12.hook_mlp_in
# blocks.12.hook_resid_mid
# blocks.12.hook_attn_out
# blocks.12.attn.hook_result
# blocks.12.attn.hook_z
# blocks.12.attn.hook_pattern
# blocks.12.attn.hook_attn_scores
# blocks.12.attn.hook_rot_k
# blocks.12.attn.hook_rot_q
# blocks.12.attn.hook_v
# blocks.12.attn.hook_k
# blocks.12.attn.hook_q
# blocks.12.ln1.hook_normalized
# blocks.12.ln1.hook_scale
# blocks.12.hook_v_input
# blocks.12.hook_k_input
# blocks.12.hook_q_input
# blocks.12.hook_resid_pre
# blocks.11.hook_resid_post
# blocks.11.hook_mlp_out
# blocks.11.mlp.hook_post
# blocks.11.mlp.hook_pre_linear
# blocks.11.mlp.hook_pre
# blocks.11.ln2.hook_normalized
# blocks.11.ln2.hook_scale
# blocks.11.hook_mlp_in
# blocks.11.hook_resid_mid
# blocks.11.hook_attn_out
# blocks.11.attn.hook_result
# blocks.11.attn.hook_z
# blocks.11.attn.hook_pattern
# blocks.11.attn.hook_attn_scores
# blocks.11.attn.hook_rot_k
# blocks.11.attn.hook_rot_q
# blocks.11.attn.hook_v
# blocks.11.attn.hook_k
# blocks.11.attn.hook_q
# blocks.11.ln1.hook_normalized
# blocks.11.ln1.hook_scale
# blocks.11.hook_v_input
# blocks.11.hook_k_input
# blocks.11.hook_q_input
# blocks.11.hook_resid_pre
# blocks.10.hook_resid_post
# blocks.10.hook_mlp_out
# blocks.10.mlp.hook_post
# blocks.10.mlp.hook_pre_linear
# blocks.10.mlp.hook_pre
# blocks.10.ln2.hook_normalized
# blocks.10.ln2.hook_scale
# blocks.10.hook_mlp_in
# blocks.10.hook_resid_mid
# blocks.10.hook_attn_out
# blocks.10.attn.hook_result
# blocks.10.attn.hook_z
# blocks.10.attn.hook_pattern
# blocks.10.attn.hook_attn_scores
# blocks.10.attn.hook_rot_k
# blocks.10.attn.hook_rot_q
# blocks.10.attn.hook_v
# blocks.10.attn.hook_k
# blocks.10.attn.hook_q
# blocks.10.ln1.hook_normalized
# blocks.10.ln1.hook_scale
# blocks.10.hook_v_input
# blocks.10.hook_k_input
# blocks.10.hook_q_input
# blocks.10.hook_resid_pre
# blocks.9.hook_resid_post
# blocks.9.hook_mlp_out
# blocks.9.mlp.hook_post
# blocks.9.mlp.hook_pre_linear
# blocks.9.mlp.hook_pre
# blocks.9.ln2.hook_normalized
# blocks.9.ln2.hook_scale
# blocks.9.hook_mlp_in
# blocks.9.hook_resid_mid
# blocks.9.hook_attn_out
# blocks.9.attn.hook_result
# blocks.9.attn.hook_z
# blocks.9.attn.hook_pattern
# blocks.9.attn.hook_attn_scores
# blocks.9.attn.hook_rot_k
# blocks.9.attn.hook_rot_q
# blocks.9.attn.hook_v
# blocks.9.attn.hook_k
# blocks.9.attn.hook_q
# blocks.9.ln1.hook_normalized
# blocks.9.ln1.hook_scale
# blocks.9.hook_v_input
# blocks.9.hook_k_input
# blocks.9.hook_q_input
# blocks.9.hook_resid_pre
# blocks.8.hook_resid_post
# blocks.8.hook_mlp_out
# blocks.8.mlp.hook_post
# blocks.8.mlp.hook_pre_linear
# blocks.8.mlp.hook_pre
# blocks.8.ln2.hook_normalized
# blocks.8.ln2.hook_scale
# blocks.8.hook_mlp_in
# blocks.8.hook_resid_mid
# blocks.8.hook_attn_out
# blocks.8.attn.hook_result
# blocks.8.attn.hook_z
# blocks.8.attn.hook_pattern
# blocks.8.attn.hook_attn_scores
# blocks.8.attn.hook_rot_k
# blocks.8.attn.hook_rot_q
# blocks.8.attn.hook_v
# blocks.8.attn.hook_k
# blocks.8.attn.hook_q
# blocks.8.ln1.hook_normalized
# blocks.8.ln1.hook_scale
# blocks.8.hook_v_input
# blocks.8.hook_k_input
# blocks.8.hook_q_input
# blocks.8.hook_resid_pre
# blocks.7.hook_resid_post
# blocks.7.hook_mlp_out
# blocks.7.mlp.hook_post
# blocks.7.mlp.hook_pre_linear
# blocks.7.mlp.hook_pre
# blocks.7.ln2.hook_normalized
# blocks.7.ln2.hook_scale
# blocks.7.hook_mlp_in
# blocks.7.hook_resid_mid
# blocks.7.hook_attn_out
# blocks.7.attn.hook_result
# blocks.7.attn.hook_z
# blocks.7.attn.hook_pattern
# blocks.7.attn.hook_attn_scores
# blocks.7.attn.hook_rot_k
# blocks.7.attn.hook_rot_q
# blocks.7.attn.hook_v
# blocks.7.attn.hook_k
# blocks.7.attn.hook_q
# blocks.7.ln1.hook_normalized
# blocks.7.ln1.hook_scale
# blocks.7.hook_v_input
# blocks.7.hook_k_input
# blocks.7.hook_q_input
# blocks.7.hook_resid_pre
# blocks.6.hook_resid_post
# blocks.6.hook_mlp_out
# blocks.6.mlp.hook_post
# blocks.6.mlp.hook_pre_linear
# blocks.6.mlp.hook_pre
# blocks.6.ln2.hook_normalized
# blocks.6.ln2.hook_scale
# blocks.6.hook_mlp_in
# blocks.6.hook_resid_mid
# blocks.6.hook_attn_out
# blocks.6.attn.hook_result
# blocks.6.attn.hook_z
# blocks.6.attn.hook_pattern
# blocks.6.attn.hook_attn_scores
# blocks.6.attn.hook_rot_k
# blocks.6.attn.hook_rot_q
# blocks.6.attn.hook_v
# blocks.6.attn.hook_k
# blocks.6.attn.hook_q
# blocks.6.ln1.hook_normalized
# blocks.6.ln1.hook_scale
# blocks.6.hook_v_input
# blocks.6.hook_k_input
# blocks.6.hook_q_input
# blocks.6.hook_resid_pre
# blocks.5.hook_resid_post
# blocks.5.hook_mlp_out
# blocks.5.mlp.hook_post
# blocks.5.mlp.hook_pre_linear
# blocks.5.mlp.hook_pre
# blocks.5.ln2.hook_normalized
# blocks.5.ln2.hook_scale
# blocks.5.hook_mlp_in
# blocks.5.hook_resid_mid
# blocks.5.hook_attn_out
# blocks.5.attn.hook_result
# blocks.5.attn.hook_z
# blocks.5.attn.hook_pattern
# blocks.5.attn.hook_attn_scores
# blocks.5.attn.hook_rot_k
# blocks.5.attn.hook_rot_q
# blocks.5.attn.hook_v
# blocks.5.attn.hook_k
# blocks.5.attn.hook_q
# blocks.5.ln1.hook_normalized
# blocks.5.ln1.hook_scale
# blocks.5.hook_v_input
# blocks.5.hook_k_input
# blocks.5.hook_q_input
# blocks.5.hook_resid_pre
# blocks.4.hook_resid_post
# blocks.4.hook_mlp_out
# blocks.4.mlp.hook_post
# blocks.4.mlp.hook_pre_linear
# blocks.4.mlp.hook_pre
# blocks.4.ln2.hook_normalized
# blocks.4.ln2.hook_scale
# blocks.4.hook_mlp_in
# blocks.4.hook_resid_mid
# blocks.4.hook_attn_out
# blocks.4.attn.hook_result
# blocks.4.attn.hook_z
# blocks.4.attn.hook_pattern
# blocks.4.attn.hook_attn_scores
# blocks.4.attn.hook_rot_k
# blocks.4.attn.hook_rot_q
# blocks.4.attn.hook_v
# blocks.4.attn.hook_k
# blocks.4.attn.hook_q
# blocks.4.ln1.hook_normalized
# blocks.4.ln1.hook_scale
# blocks.4.hook_v_input
# blocks.4.hook_k_input
# blocks.4.hook_q_input
# blocks.4.hook_resid_pre
# blocks.3.hook_resid_post
# blocks.3.hook_mlp_out
# blocks.3.mlp.hook_post
# blocks.3.mlp.hook_pre_linear
# blocks.3.mlp.hook_pre
# blocks.3.ln2.hook_normalized
# blocks.3.ln2.hook_scale
# blocks.3.hook_mlp_in
# blocks.3.hook_resid_mid
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_rot_k
# blocks.3.attn.hook_rot_q
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_mlp_out
# blocks.2.mlp.hook_post
# blocks.2.mlp.hook_pre_linear
# blocks.2.mlp.hook_pre
# blocks.2.ln2.hook_normalized
# blocks.2.ln2.hook_scale
# blocks.2.hook_mlp_in
# blocks.2.hook_resid_mid
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_rot_k
# blocks.2.attn.hook_rot_q
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_mlp_out
# blocks.1.mlp.hook_post
# blocks.1.mlp.hook_pre_linear
# blocks.1.mlp.hook_pre
# blocks.1.ln2.hook_normalized
# blocks.1.ln2.hook_scale
# blocks.1.hook_mlp_in
# blocks.1.hook_resid_mid
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_rot_k
# blocks.1.attn.hook_rot_q
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_mlp_out
# blocks.0.mlp.hook_post
# blocks.0.mlp.hook_pre_linear
# blocks.0.mlp.hook_pre
# blocks.0.ln2.hook_normalized
# blocks.0.ln2.hook_scale
# blocks.0.hook_mlp_in
# blocks.0.hook_resid_mid
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_rot_k
# blocks.0.attn.hook_rot_q
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.31.hook_resid_post, [:])
# Setting up corrupted cache
# **************************
# **************************
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# Adding sender hooks...
# Done corrupting things

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /home/obalcells/acdcpp/minimal_eap/refusal_eap.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bprivsec0.inf.ethz.ch/home/obalcells/acdcpp/minimal_eap/refusal_eap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> 1/0
#
# ZeroDivisionError: division by zero

# %%
clear_memory()
# Out:
# Cleared 296 MB. Current CUDA memory is 47638 MB.
